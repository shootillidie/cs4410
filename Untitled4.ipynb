# %% [markdown]
# <a href="https://colab.research.google.com/github/shootillidie/cs4410/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
import requests
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
# Install required nltk packages
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Fetch the text of Hamlet
target_url = "https://www.gutenberg.org/"
response = requests.get(target_url)
hamlet_text = response.text

# %%
# Tokenize the text
tokens = nltk.word_tokenize(hamlet_text.lower())

# %%
# !pip install textblob # install the textblob library
import nltk # import nltk library
from textblob import TextBlob # import TextBlob from textblob

# Fetch the text of Hamlet
target_url = "http://www.gutenberg.org/files/2265/2265.txt" # This is the correct url for Hamlet
response = requests.get(target_url)
hamlet_text = response.text

# Tokenize the text
tokens = nltk.word_tokenize(hamlet_text.lower())

data = " ".join(tokens) # convert list to string

blob = TextBlob(data) # create a TextBlob object

# %%
# Remove stopwords
stopwords = set(nltk.corpus.stopwords.words('english'))
filtered_tokens = [word for word in tokens if word.isalnum() and word not in stopwords]

# %%
# Count word frequencies
word_freq = Counter(filtered_tokens)

# %%
# Bar Chart
most_common_words = word_freq.most_common(20)
words, counts = zip(*most_common_words)

# %%
plt.figure(figsize=(10, 6))
plt.bar(words, counts, color='blue')
plt.xlabel('Word')
plt.ylabel('Frequency')
plt.title('Top 20 Words in Hamlet')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Word Cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)

# %%
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
